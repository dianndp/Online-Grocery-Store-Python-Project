# %% [markdown]
# # Direction 1
# #### Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %% [markdown]
# # Import Librarie

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Datasets

# %%
path=(r'C:\Users\Admin\Desktop\Data Tasks\Data Immersion\Achievement 4\Instacart Basket Analysis\02 data')

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path,'Prepared Data','df_ords_prods.pkl'))

# %% [markdown]
# # Direction 2
# #### In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#checking df
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_label  \
# ...

# %%
#dropping merge column to save space
ords_prods_merge=ords_prods_merge.drop(columns=['_merge'])

# %%
#grouping df by department id and displaying the mean of the order number in each department
ords_prods_merge.groupby('department_id').agg({'order_number':'mean'})
# Out:
#                order_number
# department_id
# 1                 15.457838
# 2                 17.277920
# 3                 17.170395
# 4                 17.811403
# 5                 15.215751
# 6                 16.439806
# 7                 17.225802
# 8                 15.340650
# 9                 15.895474
# 10                20.197148
# 11                16.170638
# 12                15.887671
# 13                16.583536
# 14                16.773669
# 15                16.165037
# 16                17.665606
# 17                15.694469
# 18                19.310397
# 19                17.177343
# 20                16.473447
# 21                22.902379

# %% [markdown]
# # Direction 3
# #### Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
#creating a subset of first 1000000 rows
df=ords_prods_merge[:1000000]

# %%
#checking the new df
df.shape
# Out:
# (1000000, 16)

# %%
#grouping df by department id and displaying the mean of the order number in each department
df.groupby('department_id').agg({'order_number':'mean'})
# Out:
#                order_number
# department_id
# 4                 18.825780
# 7                 17.472355
# 13                17.993423
# 14                19.246334
# 16                19.463012
# 17                11.294069
# 19                19.305237
# 20                17.599636

# %% [markdown]
# ##### 1. In the smaller subset the average found for each department is higher than that in the entire dataframe( except department 17). Thus, the order number variables in the rest of the data set are lower (and higher for department 17).
# ##### 2. In the first 1000000 rows only products for 8 departments listed above were sold.

# %% [markdown]
# # Direction 4
# #### Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#creating column with max order for each user
ords_prods_merge['max_order']=ords_prods_merge.groupby('user_id')['order_number'].transform(np.max)

# %%
#checking the results
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ##### creating loyalty flag

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10,'loyalty_flag']='New customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']>10) & (ords_prods_merge['max_order']<=40),'loyalty_flag']='Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag']='Loyal customer'

# %%
#checking the count for each flag
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
#checking the output of the loyalty flag
ords_prods_merge[['user_id','max_order','loyalty_flag']].head(30)
# Out:
#     user_id  max_order      loyalty_flag
# 0         1         10      New customer
# 1         1         10      New customer
# 2         1         10      New customer
# 3         1         10      New customer
# 4         1         10      New customer
# 5         1         10      New customer
# 6         1         10      New customer
# 7         1         10      New customer
# 8         1         10      New customer
# 9         1         10      New customer
# 10       15         22  Regular customer
# 11       15         22  Regular customer
# 12       15         22  Regular customer
# 13       15         22  Regular customer
# 14       15         22  Regular customer
# 15       19          9      New customer
# 16       19          9      New customer
# 17       19          9      New customer
# 18       21         33  Regular customer
# 19       31         20  Regular customer
# 20       31         20  Regular customer
# 21       43         11  Regular customer
# ...

# %% [markdown]
# # Direction 5
# #### The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','median','max','min','sum','count']})
# Out:
#                      prices
#                        mean median      max  min          sum     count
# loyalty_flag
# Loyal customer    10.386335    7.4  99999.0  1.0  106814040.0  10284093
# New customer      13.294669    7.4  99999.0  1.0   83011784.0   6243990
# Regular customer  12.495717    7.4  99999.0  1.0  198391696.0  15876776

# %% [markdown]
# ##### Note: Even though the loyal customer have more orders than the regular and new ones, the product prices are on average smaller.
# Most of the clients are regular

# %%
#checking which product has the price 99999
df_price_99999=ords_prods_merge.loc[ords_prods_merge['prices']==99999.0]
df_price_99999
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 29165516    183964      873             3                   0
# 29165517   1851256      873             4                   6
# 29165518   1915696     1893             1                   5
# 29165519   2763293     1893             2                   4
# 29165520   2564805     1893             4                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 29165516                 10                     7.0       33664
# 29165517                 12                    13.0       33664
# ...

# %%
df_price_99999['product_id'].value_counts()
# Out:
# product_id
# 33664    698
# Name: count, dtype: int64

# %% [markdown]
# #### Note: It's highly unlikely that a milk can have a price as high as 99999. If possible, I would like to ask a superior the right price. Otherwise the number can be assigned a NaN value in order to have the results of the descriptive analytics plausible.

# %% [markdown]
# # Direction 6
# #### The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# #### If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# #### If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %% [markdown]
# ##### step 1:finding the mean of price for each user

# %%
ords_prods_merge['prices_mean']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_label  \
# ...

# %% [markdown]
# ##### step2: creating a spending flag

# %%
ords_prods_merge.loc[ords_prods_merge['prices_mean']<10,'spending_flag']='Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['prices_mean']>10,'spending_flag']='High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(normalize=False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      633864
# Name: count, dtype: int64

# %% [markdown]
# # Direction 7
# #### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %% [markdown]
# ####  step 1:ffinding the median of time since last order

# %%
#creating the median in the “days_since_prior_order” column
ords_prods_merge['order_median']=ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform(np.median)

# %%
#checking the new column
ords_prods_merge[['user_id','days_since_prior_order','order_median']]
# Out:
#           user_id  days_since_prior_order  order_median
# 0               1                     NaN          20.5
# 1               1                    15.0          20.5
# 2               1                    21.0          20.5
# 3               1                    29.0          20.5
# 4               1                    28.0          20.5
# ...           ...                     ...           ...
# 32404854   202557                     1.0           8.0
# 32404855   202557                     3.0           8.0
# 32404856   203436                     NaN          15.0
# 32404857   203436                    15.0          15.0
# 32404858   205420                     NaN          13.0
#
# [32404859 rows x 3 columns]

# %% [markdown]
# #### step2: creating a frequency flag

# %%
ords_prods_merge.loc[ords_prods_merge['order_median']<=10,'frequency_flag']='Frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['order_median']>10)&(ords_prods_merge['order_median']<=20),'frequency_flag']='Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['order_median']>20,'frequency_flag']='Non-frequent customer'

# %%
#checking df
ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
#checking frequency status
ords_prods_merge['frequency_flag'].value_counts()
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# Name: count, dtype: int64

# %% [markdown]
# # Direction 9
# #### Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(os.path.join(path,'Prepared data','ords_prods_merge_frequency_flags.pkl'))
